# %%
# %reload_ext autoreload

import os 
import pandas as pd 
import tensorflow as tf 
import plotly.express as px

from utils import (show_class_distribution, fix_images, 
                   get_files_by_class , plot_class_distribution , 
                   create_train_test_val_split, compute_class_weights_from_directory, evaluate_binary_model, show_samples_per_class, sanity_check_labels,
                    get_true_and_proba , scan_thresholds)
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## EDA

# %% [markdown]
# We will begin by fixing the images and make sure we are removing any image not compatible with TensorFlow.

# %%
ROOT_DIR = "./data"
DATA_DIR = f"{ROOT_DIR}/data"
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
SEED = 42
LEARNING_RATE = 3e-4
EPOCHS = 10

# %%
show_class_distribution(DATA_DIR)
# Out:
# Class: S1SAR_UnBalanced_400by400_Class_0 - Number of samples: 3725
# Class: Samples - Number of samples: 8
# Class: S1SAR_UnBalanced_400by400_Class_1 - Number of samples: 1905

# %%
fix_images(DATA_DIR)
# Out:
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/422_10000_6200_img_8UXGVkszCbidTR49_GBR_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/2857_9000_11200_img_NgkRiqvlSMUKRxSO_GBR_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/0_0_0_img_CFAY073B8sznfZJG_GBR_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/2_400_0_img_0t9JBHeOeBHgaLmJ_JAV_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/2690_2600_9400_img_8jmWSIh9LhIh4p4e_GBR_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/15_600_600_img_yypoVwlHZPchMcLa_GBR_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/1064_9200_7400_img_xCVKEyUQBMP2ef8r_GBR_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/460_5400_3000_img_lHgjbs0x2eQq1CKp_GBR_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/339_13800_3800_img_rnWmTKyBF7zabkrd_GBR_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/1481_5400_6800_img_D6EXEnXtm3ouAr1e_GBR_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/1_200_0_img_lqw40SwG5UkQ0NrR_ADR_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/0_0_0_img_HxrkYQnQN8oFI7CW_LUC_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/2_400_0_img_azWgqGsnZbKfcsXY_GBR_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/947_14400_4600_img_ki84WJ0wWEXyoqFG_GBR_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/0_0_0_img_a5RDr0etsfy7JXbq_BOR_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/3_600_0_img_CMeS5mtBIIVNFdOM_JAV_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/0_0_0_img_aLZsXLqyivTR36hT_GBR_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/2_400_0_img_08fnlfmZCtdTHJgt_JAV_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/2192_3400_10200_img_vWmEXWwcH5idWAa5_GBR_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/0_0_0_img_U8uOmBDXWSa1jD8Q_MLA_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/1215_7600_4600_img_BQgOzUjDD8V0N8wF_SIN_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/0_0_0_img_pmNBTTootjKmb2Bh_BAH_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/2486_12800_8600_img_X4LzRUv4N1YZYwoN_SIN_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/1_200_0_img_6io3fynLgXVWZpTh_GBR_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/1704_10400_8400_img_t1NOUdNqgGflJFx4_GBR_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/1831_7600_7400_img_bSopyZZGSWgsIxVf_GBR_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/1700_8600_8400_img_d1vVTuPhBt8tIDb8_GBR_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/771_11400_4800_img_PXR8n83Wkbb9ToNq_GBR_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/1868_6800_8200_img_kxlQ7aJdWKzVjknW_GBR_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/2424_13400_8400_img_3tyNMtEJYeQhzR9p_SIN_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/0_0_0_img_53QuDvSIU1JXAhko_GBR_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/1707_9400_6000_img_xRV7eltbu2600T1Y_SIN_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/705_12000_7200_img_Z8TS3PQIXjz6Eh6M_GBR_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/261_13800_3800_img_Hv0uKogNwmzpdbcm_GBR_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/346_10600_5800_img_tXdFexlbBY5QglP0_GBR_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/1587_9400_7800_img_racwODvgjDNdAHaM_GBR_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/1856_2000_6600_img_TgB5876SnBP6EK40_SIN_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/1756_10800_6200_img_W3bzgkBYgzMly34m_GBR_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/1085_6800_5800_img_t7XWDzD5kJ5NYR1K_GBR_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/0_0_0_img_3ug0Pdb1Ta6bgzds_SFr_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/930_12600_10200_img_iVTR6AqIIOhUTb1d_GBR_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/0_0_0_img_xFHi5Ujq9VWX0E6E_GBR_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/1329_1400_5000_img_XgLpYk9oBlwfZ9Qh_SIN_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/2575_7000_8600_img_pUiSIjZbYF6dXbGE_GBR_cls_0.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_0/0/
SIN_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/3_600_0_img_VXuv1oebj5nekofz_JAV_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/2_400_0_img_moSaCccYIeBzd5Tc_JAV_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/578_12200_2800_img_CJ8KjU50i2B6fPMD_GBR_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/11_600_400_img_HpXIUdXE2E15V1oS_GBR_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/2208_3600_7600_img_Ebp6vm8eBd4a5L2i_SIN_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/11_600_400_img_4juq00SlRdysTTsr_GBR_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/0_0_0_img_0bBRglmdLdC6cFxF_JAV_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/0_0_0_img_G4yxsyYU5ZgSkylB_JAV_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/2_400_0_img_lQPkKVcgCulwJP8N_JAV_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/2_400_0_img_8QL7PlsOIgRIsUVS_JAV_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/0_0_0_img_fAXdZILhUYKyi5yC_EGY_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/1960_4800_7400_img_pcygBUVgchVZowe9_SIN_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/4_0_200_img_BfqJN2FHwfbTfc5B_JAV_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/2_400_0_img_Pp37NyvpKwpVYquZ_BOR_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/3_600_0_img_1TDZ4mPosbER_VEN_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/3_600_0_img_Dh1OoKmlslVAg6IH_JAV_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/8_0_400_img_hWkOHLzUmENaSn5a_PHI_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/4_0_200_img_K5InbHW3BBXHczW5_ADR_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/0_0_0_img_JpiIZN3pVmaym4T9_JAV_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/1_200_0_img_sU40R8YtO20CBytM_GBR_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/8_0_400_img_e0ltJbJmM6OhWK8k_JAV_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/2_400_0_img_RYyVktSw3mciYrjj_PHI_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/12_0_600_img_DOlPHIOr3NSGzCYu_LUC_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/1_200_0_img_hlATGTYl0iRPsmhs_JAV_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/1_200_0_img_CTP7sf0vbf9TYPJ7_BAH_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/119_8200_1000_img_GPb3Uf8ZKkXPDVGx_SIN_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/2_400_0_img_Qnh4pkszKRBySrfk_JAV_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/0_0_0_img_ba2IUA6diZwv1kYh_JAV_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/1_200_0_img_TPiDA024JwwzVqSg_GBR_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/6_400_200_img_0JPZyDl8TsrA4Fli_JAV_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/1_200_0_img_BTVaT4Uxop7F9Jmk_JAV_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/6_400_200_img_pC6pVd0lFTuBuH5R_PHI_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/4_0_200_img_yypoVwlHZPchMcLa_GBR_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/10_400_400_img_RUJoqEthFrbkKwoJ_GBR_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/1_200_0_img_FlAv1fwf5zOtuwQW_JAV_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/4_0_200_img_1nb7rUyqBdfrYHhn_JAV_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/1478_3400_5400_img_93H5epg1XYmWaAJO_SIN_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/7_600_200_img_MFzmL0hgg3qkq3he_EGY_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/644_12400_9600_img_00LPvC6gSlj0eWLe_GBR_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/591_12800_3800_img_pVLzEWIy3oOYLKhw_GBR_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/2006_12000_8000_img_jTV4IhGXFRDFfaWh_GBR_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/1_200_0_img_yabtEjh8oBCpixtH_JAV_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/610_3400_2800_img_ja7O9V675jx1QFbr_SIN_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/6_400_200_img_SyumdaQ4btQAYZqS_JAV_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/5_200_200_img_0cKipkZKSSNVdT6P_JAV_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/3_600_0_img_89byNuE8dsDeXzkq_JAV_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/5_200_200_img_0JPZyDl8TsrA4Fli_JAV_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/2_400_0_img_CT0of3jw4SX8EVza_JAV_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/7_600_200_img_cDgWCSXoNP1b0kAg_JAV_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/0_0_0_img_DQmdzllFUcx4vAZD_GBR_cls_1.jpg of type: jpeg
# Accepted file: data/data/S1SAR_UnBalanced_400by400_Class_1/1/1961_5000_7400_img_WFmEi4VkAoK4Agqi_SIN_cls_1.jpg of type: jpeg
# Image fixing completed.

# %%
show_class_distribution(DATA_DIR)
# Out:
# Class: S1SAR_UnBalanced_400by400_Class_0 - Number of samples: 3725
# Class: Samples - Number of samples: 8
# Class: S1SAR_UnBalanced_400by400_Class_1 - Number of samples: 1905

# %%
plot_class_distribution(DATA_DIR)

# %% [markdown]
# We can observe that we have an unbalanced dataset , which will require data augmentation.

# %% [markdown]
# **TRAIN / TEST / VAL Split**

# %%
create_train_test_val_split(
    DATA_DIR,
    allowed_classes=[
        "S1SAR_UnBalanced_400by400_Class_0",
        "S1SAR_UnBalanced_400by400_Class_1"
    ]
)
# Out:
# Skipping class: Samples as it's not in allowed_classes
# Dataset split completed. Organized data saved to: data/organized

# %%
plot_class_distribution("data/organized")

# %%
plot_class_distribution("data/organized/train")

# %%
plot_class_distribution("data/organized/test")

# %%
plot_class_distribution("data/organized/val")

# %% [markdown]
# **LOADING DATASETS WITH KERAS**

# %%
tf.random.set_seed(SEED)

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    f"{ROOT_DIR}/organized/train",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    seed=SEED
)
val_ds = tf.keras.utils.image_dataset_from_directory(
    f"{ROOT_DIR}/organized/val",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    seed=SEED
)
test_ds = tf.keras.utils.image_dataset_from_directory(
    f"{ROOT_DIR}/organized/test",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    seed=SEED
)
# Out:
# Found 3940 files belonging to 2 classes.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771470844.960046  542766 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 11934 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080 SUPER, pci bus id: 0000:07:00.0, compute capability: 8.9
# Found 845 files belonging to 2 classes.
# Found 845 files belonging to 2 classes.

# %%
show_samples_per_class(train_ds)

# %%
sanity_check_labels(train_ds, DATA_DIR)
# Out:
# ✅ Sanity check passed. All files match expected class folders.

# %%
# This will optimize the dataset for performance by prefetching data while the model is training
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# We compute the class weights to handle the unbalanced dataset

# %%
class_weight = compute_class_weights_from_directory(f"{ROOT_DIR}/organized/train")
print(class_weight)
# Out:
# {0: 0.7556578442654392, 1: 1.4778694673668418}

# %% [markdown]
# Data augmentation is applied exclusively to the training set.
# Given the radar-specific nature of Sentinel-1 SAR imagery, augmentations are kept conservative to avoid altering the physical properties of the signal.

# %%
data_ag = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.03),
])

# %% [markdown]
# # TRAINING

# %% [markdown]
# **BASELINE MODEL**
# A simple CNN to start with.

# %%
model = tf.keras.Sequential([
    data_ag,
    tf.keras.layers.Rescaling(1./255),
    tf.keras.layers.Conv2D(32,3, padding="same"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Conv2D(64,3, padding="same"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Conv2D(128,3, padding="same"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128),
    tf.keras.layers.ReLU(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=8,
    restore_best_weights=True
)

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    # class_weight=class_weight,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/10
# 2026-02-19 04:14:08.634755: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91900
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 0.6480 - loss: 1.5812 - val_accuracy: 0.3385 - val_loss: 0.7601
# Epoch 2/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - accuracy: 0.6622 - loss: 0.6351 - val_accuracy: 0.6615 - val_loss: 0.6712
# Epoch 3/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - accuracy: 0.6617 - loss: 0.6283 - val_accuracy: 0.6615 - val_loss: 0.6533
# Epoch 4/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - accuracy: 0.6617 - loss: 0.6245 - val_accuracy: 0.6615 - val_loss: 0.6524
# Epoch 5/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - accuracy: 0.6617 - loss: 0.6152 - val_accuracy: 0.6615 - val_loss: 0.6081
# Epoch 6/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - accuracy: 0.6617 - loss: 0.6294 - val_accuracy: 0.6615 - val_loss: 0.6177
# Epoch 7/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - accuracy: 0.6617 - loss: 0.6243 - val_accuracy: 0.6615 - val_loss: 0.6109
# Epoch 8/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - accuracy: 0.6617 - loss: 0.6211 - val_accuracy: 0.6615 - val_loss: 0.6023
# Epoch 9/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - accuracy: 0.6617 - loss: 0.6188 - val_accuracy: 0.6615 - val_loss: 0.6047
# Epoch 10/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - accuracy: 0.6617 - loss: 0.6210 - val_accuracy: 0.6615 - val_loss: 0.5906

# %%
model.evaluate(test_ds)
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6615 - loss: 0.5768
# [0.5768436193466187, 0.6615384817123413]

# %%
y_true, y_pred = evaluate_binary_model(model, test_ds);
# Out:
# True distribution: [559 286]
# Predicted distribution: [845]
#
# Confusion Matrix:
# [[559   0]
#  [286   0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.66      1.00      0.80       559
#            1       0.00      0.00      0.00       286
#
#     accuracy                           0.66       845
#    macro avg       0.33      0.50      0.40       845
# weighted avg       0.44      0.66      0.53       845
# 2026-02-19 04:15:10.790023: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/andrealoy/Documents/repos/sentinel-1-oil-detection/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /home/andrealoy/Documents/repos/sentinel-1-oil-detection/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /home/andrealoy/Documents/repos/sentinel-1-oil-detection/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %% [markdown]
# Here , we can see that the model doesn't converge very much with an accuracy at 72%.

# %%
pd.DataFrame(history.history).plot()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()

# %%
def build_improved_cnn(input_shape=(224,224,3)):

    inputs = tf.keras.Input(shape=input_shape)

    x = tf.keras.layers.Rescaling(1./255)(inputs)

    # Bloc 1
    x = tf.keras.layers.Conv2D(32, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.ReLU()(x)
    x = tf.keras.layers.MaxPooling2D()(x)

    # Bloc 2
    x = tf.keras.layers.Conv2D(64, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.ReLU()(x)
    x = tf.keras.layers.MaxPooling2D()(x)

    # Bloc 3
    x = tf.keras.layers.Conv2D(128, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.ReLU()(x)
    x = tf.keras.layers.MaxPooling2D()(x)

    # Bloc 4 (nouveau)
    x = tf.keras.layers.Conv2D(256, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.ReLU()(x)
    x = tf.keras.layers.MaxPooling2D()(x)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    x = tf.keras.layers.Dense(128)(x)
    x = tf.keras.layers.ReLU()(x)
    x = tf.keras.layers.Dropout(0.3)(x)

    outputs = tf.keras.layers.Dense(1, activation="sigmoid")(x)

    model = tf.keras.Model(inputs, outputs)

    return model

# %%
model_improved = build_improved_cnn()

model_improved.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss="binary_crossentropy",
    metrics=[
        "accuracy",
        tf.keras.metrics.Precision(),
        tf.keras.metrics.Recall(),
        tf.keras.metrics.AUC(name="auc")
    ]
)
history_improved = model_improved.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    # class_weight=class_weight,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/10
# 2026-02-19 04:15:12.212732: I external/local_xla/xla/service/service.cc:163] XLA service 0x718ca0033030 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-02-19 04:15:12.212757: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 4080 SUPER, Compute Capability 8.9
# 2026-02-19 04:15:12.252631: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-02-19 04:15:12.564172: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-19 04:15:12.564188: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-19 04:15:12.564195: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-19 04:15:12.799726: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1226', 4 bytes spill stores, 4 bytes spill loads
#
# 2026-02-19 04:15:12.940247: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1226', 20 bytes spill stores, 20 bytes spill loads
#
# 2026-02-19 04:15:13.084879: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2362', 520 bytes spill stores, 520 bytes spill loads
#   7/124 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.5757 - auc: 0.6072 - loss: 0.7555 - precision: 0.3395 - recall: 0.7185
# I0000 00:00:1771470916.085095  543903 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - accuracy: 0.7140 - auc: 0.7232 - loss: 0.5829 - precision: 0.6006 - recall: 0.4614 - val_accuracy: 0.3385 - val_auc: 0.6280 - val_loss: 0.8420 - val_precision: 0.3385 - val_recall: 1.0000
# Epoch 2/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.7338 - auc: 0.7635 - loss: 0.5416 - precision: 0.6514 - recall: 0.4584 - val_accuracy: 0.4107 - val_auc: 0.6284 - val_loss: 0.7770 - val_precision: 0.3540 - val_recall: 0.8986
# Epoch 3/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.7426 - auc: 0.7851 - loss: 0.5232 - precision: 0.6562 - recall: 0.5026 - val_accuracy: 0.4970 - val_auc: 0.6972 - val_loss: 0.7303 - val_precision: 0.3866 - val_recall: 0.8287
# Epoch 4/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.7566 - auc: 0.8013 - loss: 0.5074 - precision: 0.6767 - recall: 0.5371 - val_accuracy: 0.6876 - val_auc: 0.7483 - val_loss: 0.6079 - val_precision: 0.5288 - val_recall: 0.7063
# Epoch 5/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.7678 - auc: 0.8101 - loss: 0.4980 - precision: 0.6924 - recall: 0.5641 - val_accuracy: 0.7089 - val_auc: 0.7791 - val_loss: 0.5524 - val_precision: 0.5549 - val_recall: 0.7063
# Epoch 6/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.7759 - auc: 0.8270 - loss: 0.4793 - precision: 0.6988 - recall: 0.5934 - val_accuracy: 0.7527 - val_auc: 0.8071 - val_loss: 0.5179 - val_precision: 0.6170 - val_recall: 0.7098
# Epoch 7/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.7873 - auc: 0.8361 - loss: 0.4676 - precision: 0.7114 - recall: 0.6249 - val_accuracy: 0.7243 - val_auc: 0.8125 - val_loss: 0.5279 - val_precision: 0.5714 - val_recall: 0.7413
# Epoch 8/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.7987 - auc: 0.8508 - loss: 0.4511 - precision: 0.7277 - recall: 0.6474 - val_accuracy: 0.7479 - val_auc: 0.8152 - val_loss: 0.5135 - val_precision: 0.6070 - val_recall: 0.7238
# Epoch 9/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.8043 - auc: 0.8592 - loss: 0.4395 - precision: 0.7349 - recall: 0.6594 - val_accuracy: 0.7467 - val_auc: 0.7725 - val_loss: 0.5285 - val_precision: 0.6417 - val_recall: 0.5699
# Epoch 10/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.8081 - auc: 0.8617 - loss: 0.4352 - precision: 0.7402 - recall: 0.6669 - val_accuracy: 0.6497 - val_auc: 0.7806 - val_loss: 0.5895 - val_precision: 0.4887 - val_recall: 0.7552

# %%
model_improved.evaluate(test_ds)
evaluate_binary_model(model_improved, test_ds);
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7775 - auc: 0.8260 - loss: 0.4968 - precision: 0.6541 - recall: 0.7273
# True distribution: [559 286]
# Predicted distribution: [527 318]
#
# Confusion Matrix:
# [[449 110]
#  [ 78 208]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.80      0.83       559
#            1       0.65      0.73      0.69       286
#
#     accuracy                           0.78       845
#    macro avg       0.75      0.77      0.76       845
# weighted avg       0.79      0.78      0.78       845
# 2026-02-19 04:15:52.584278: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
y_val_true, y_val_proba = get_true_and_proba(model_improved, val_ds)
results = scan_thresholds(y_val_true, y_val_proba)
# Out:
# threshold | precision | recall | f1
# ------------------------------------
#     0.10 |     0.393 |  0.979 |  0.561
#     0.15 |     0.407 |  0.951 |  0.570
#     0.20 |     0.429 |  0.937 |  0.589
#     0.25 |     0.462 |  0.906 |  0.612
#     0.30 |     0.489 |  0.864 |  0.625
#     0.35 |     0.521 |  0.822 |  0.638
#     0.40 |     0.551 |  0.794 |  0.650
#     0.45 |     0.588 |  0.759 |  0.663
#     0.50 |     0.607 |  0.724 |  0.660
#     0.55 |     0.642 |  0.696 |  0.668
#     0.60 |     0.668 |  0.647 |  0.657
#     0.65 |     0.706 |  0.570 |  0.631
#     0.70 |     0.704 |  0.483 |  0.573
#     0.75 |     0.726 |  0.399 |  0.515
#     0.80 |     0.813 |  0.304 |  0.443
#     0.85 |     1.000 |  0.122 |  0.218

# %%
pd.DataFrame(history_improved.history).plot()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()

# %%
def build_efficientnet(input_shape=(224,224,3)):
    # EfficientNetB0 s'attend à des inputs entre [0, 255] par défaut dans Keras
    base_model = tf.keras.applications.EfficientNetB0(
        include_top=False,
        weights="imagenet",
        input_shape=input_shape
    )

    base_model.trainable = False 

    inputs = tf.keras.Input(shape=input_shape)

    # --- CORRECTION ICI : ON RETIRE LE RESCALING ---
    # On passe directement les inputs au base_model
    # EfficientNet s'occupe de la normalisation en interne
    x = base_model(inputs, training=False) 

    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(1, activation="sigmoid")(x)

    model = tf.keras.Model(inputs, outputs)

    return model

# %%
efficient_net_model = build_efficientnet()

efficient_net_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss="binary_crossentropy",
    metrics=[
        "accuracy",
        tf.keras.metrics.Precision(),
        tf.keras.metrics.Recall()
    ]
)

history_efficient_net = efficient_net_model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    # class_weight=class_weight,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 17s 79ms/step - accuracy: 0.7183 - loss: 0.5599 - precision_2: 0.6939 - recall_2: 0.2993 - val_accuracy: 0.8426 - val_loss: 0.4583 - val_precision_2: 0.9371 - val_recall_2: 0.5734
# Epoch 2/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8317 - loss: 0.4338 - precision_2: 0.8587 - recall_2: 0.6017 - val_accuracy: 0.8876 - val_loss: 0.3753 - val_precision_2: 0.9244 - val_recall_2: 0.7273
# Epoch 3/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8726 - loss: 0.3640 - precision_2: 0.8726 - recall_2: 0.7299 - val_accuracy: 0.8923 - val_loss: 0.3322 - val_precision_2: 0.9079 - val_recall_2: 0.7587
# Epoch 4/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8764 - loss: 0.3369 - precision_2: 0.8704 - recall_2: 0.7457 - val_accuracy: 0.8970 - val_loss: 0.3066 - val_precision_2: 0.8933 - val_recall_2: 0.7902
# Epoch 5/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8838 - loss: 0.3156 - precision_2: 0.8711 - recall_2: 0.7704 - val_accuracy: 0.9018 - val_loss: 0.2882 - val_precision_2: 0.8980 - val_recall_2: 0.8007
# Epoch 6/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8926 - loss: 0.3032 - precision_2: 0.8785 - recall_2: 0.7922 - val_accuracy: 0.9053 - val_loss: 0.2753 - val_precision_2: 0.8992 - val_recall_2: 0.8112
# Epoch 7/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8975 - loss: 0.2890 - precision_2: 0.8817 - recall_2: 0.8050 - val_accuracy: 0.9089 - val_loss: 0.2647 - val_precision_2: 0.9035 - val_recall_2: 0.8182
# Epoch 8/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8934 - loss: 0.2860 - precision_2: 0.8757 - recall_2: 0.7982 - val_accuracy: 0.9077 - val_loss: 0.2569 - val_precision_2: 0.8910 - val_recall_2: 0.8287
# Epoch 9/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9005 - loss: 0.2754 - precision_2: 0.8773 - recall_2: 0.8207 - val_accuracy: 0.9101 - val_loss: 0.2492 - val_precision_2: 0.9038 - val_recall_2: 0.8217
# Epoch 10/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8997 - loss: 0.2697 - precision_2: 0.8825 - recall_2: 0.8117 - val_accuracy: 0.9101 - val_loss: 0.2423 - val_precision_2: 0.9038 - val_recall_2: 0.8217

# %%
pd.DataFrame(history_efficient_net.history).plot()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()

# %%
efficient_net_model.evaluate(test_ds)
evaluate_binary_model(efficient_net_model, test_ds);
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9006 - loss: 0.2683 - precision_2: 0.8915 - recall_2: 0.8042
# True distribution: [559 286]
# Predicted distribution: [587 258]
#
# Confusion Matrix:
# [[531  28]
#  [ 56 230]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.93       559
#            1       0.89      0.80      0.85       286
#
#     accuracy                           0.90       845
#    macro avg       0.90      0.88      0.89       845
# weighted avg       0.90      0.90      0.90       845

# %%
# 1. Dégeler le modèle de base
efficient_net_model.trainable = True

# 2. On veut affiner, pas tout casser. On ne garde que les 20 dernières couches entraînables.
# EfficientNetB0 a environ 230 couches.
for layer in efficient_net_model.layers[:-20]:
    layer.trainable = False

# 3. COMPILATION CRITIQUE : Il faut un Learning Rate très bas (10x ou 100x plus petit)
# Si vous gardez 3e-4, vous allez détruire les poids actuels.
efficient_net_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),  # Notez le 1e-5
    loss="binary_crossentropy",
    metrics=["accuracy", tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
)

# 4. On relance l'entraînement pour quelques epochs (Fine-tuning)
history_fine = efficient_net_model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10,  # Souvent 5-10 suffisent
    class_weight=class_weight, # Toujours garder les poids !
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 18s 82ms/step - accuracy: 0.9018 - loss: 0.2988 - precision_3: 0.8695 - recall_3: 0.8350 - val_accuracy: 0.9136 - val_loss: 0.2430 - val_precision_3: 0.9019 - val_recall_3: 0.8357
# Epoch 2/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9058 - loss: 0.2885 - precision_3: 0.8694 - recall_3: 0.8492 - val_accuracy: 0.9124 - val_loss: 0.2440 - val_precision_3: 0.8926 - val_recall_3: 0.8427
# Epoch 3/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9030 - loss: 0.2867 - precision_3: 0.8644 - recall_3: 0.8462 - val_accuracy: 0.9101 - val_loss: 0.2454 - val_precision_3: 0.8777 - val_recall_3: 0.8531
# Epoch 4/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9066 - loss: 0.2882 - precision_3: 0.8669 - recall_3: 0.8552 - val_accuracy: 0.9124 - val_loss: 0.2469 - val_precision_3: 0.8759 - val_recall_3: 0.8636
# Epoch 5/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9058 - loss: 0.2839 - precision_3: 0.8547 - recall_3: 0.8695 - val_accuracy: 0.9148 - val_loss: 0.2483 - val_precision_3: 0.8768 - val_recall_3: 0.8706
# Epoch 6/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9000 - loss: 0.2828 - precision_3: 0.8455 - recall_3: 0.8620 - val_accuracy: 0.9148 - val_loss: 0.2499 - val_precision_3: 0.8690 - val_recall_3: 0.8811
# Epoch 7/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8992 - loss: 0.2815 - precision_3: 0.8333 - recall_3: 0.8777 - val_accuracy: 0.9148 - val_loss: 0.2508 - val_precision_3: 0.8639 - val_recall_3: 0.8881
# Epoch 8/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9030 - loss: 0.2820 - precision_3: 0.8413 - recall_3: 0.8792 - val_accuracy: 0.9160 - val_loss: 0.2517 - val_precision_3: 0.8644 - val_recall_3: 0.8916

# %%
pd.DataFrame(history_fine.history).plot()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()

# %%
efficient_net_model.evaluate(test_ds)
evaluate_binary_model(efficient_net_model, test_ds);
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9041 - loss: 0.2680 - precision_3: 0.8897 - recall_3: 0.8182
# True distribution: [559 286]
# Predicted distribution: [582 263]
#
# Confusion Matrix:
# [[530  29]
#  [ 52 234]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93       559
#            1       0.89      0.82      0.85       286
#
#     accuracy                           0.90       845
#    macro avg       0.90      0.88      0.89       845
# weighted avg       0.90      0.90      0.90       845

# %%
efficient_net_model.evaluate(test_ds)
evaluate_binary_model(efficient_net_model, test_ds);

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

def visualize_worst_errors(model, dataset, num_images=5):
    # 1. Extraire toutes les images et labels du dataset de test
    # (Attention : cela charge tout le dataset de test en RAM, 
    # c'est ok pour 845 images, mais attention si vous aviez 100k images)
    print("Extraction des images et prédictions...")
    images = []
    labels = []
    
    for img_batch, label_batch in dataset:
        images.append(img_batch.numpy())
        labels.append(label_batch.numpy())
        
    X_test = np.concatenate(images)
    y_true = np.concatenate(labels)
    
    # 2. Faire les prédictions
    # On prédit sur le tableau numpy pour être sûr de l'ordre
    y_pred_probs = model.predict(X_test, verbose=0).flatten()
    
    # 3. Identifier les erreurs
    # Seuil standard de 0.5 pour définir l'erreur
    y_pred_binary = (y_pred_probs > 0.5).astype(int)
    
    # Indices des erreurs
    fp_indices = np.where((y_true == 0) & (y_pred_binary == 1))[0] # Faux Positifs
    fn_indices = np.where((y_true == 1) & (y_pred_binary == 0))[0] # Faux Négatifs
    
    print(f"Total Faux Positifs : {len(fp_indices)}")
    print(f"Total Faux Négatifs : {len(fn_indices)}")
    
    # 4. Trier par "gravité" (Confiance du modèle)
    # Pires FP : Le modèle a prédit une proba proche de 1.0 (très sûr de lui) alors que c'est 0
    worst_fp = fp_indices[np.argsort(y_pred_probs[fp_indices])[::-1][:num_images]]
    
    # Pires FN : Le modèle a prédit une proba proche de 0.0 (très sûr de lui) alors que c'est 1
    worst_fn = fn_indices[np.argsort(y_pred_probs[fn_indices])[:num_images]]
    
    # 5. Fonction d'affichage
    def plot_images(indices, title_prefix):
        if len(indices) == 0:
            print(f"Pas d'erreurs trouvées pour : {title_prefix}")
            return
            
        plt.figure(figsize=(15, 5))
        for i, idx in enumerate(indices):
            plt.subplot(1, num_images, i + 1)
            
            # Gestion de l'affichage (uint8 vs float)
            img = X_test[idx]
            if img.max() > 1.0:
                img = img.astype("uint8")
            
            plt.imshow(img)
            plt.title(f"Vrai: {y_true[idx]} | Pred: {y_pred_probs[idx]:.4f}")
            plt.axis("off")
        plt.suptitle(title_prefix, fontsize=16)
        plt.tight_layout()
        plt.show()

    # Afficher
    plot_images(worst_fp, "Pires Faux Positifs (Modèle voit du pétrole partout)")
    plot_images(worst_fn, "Pires Faux Négatifs (Modèle rate le pétrole)")

# Lancer la visualisation
visualize_worst_errors(efficient_net_model, test_ds)
# Out:
# Extraction des images et prédictions...
# 2026-02-19 04:35:23.447831: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Total Faux Positifs : 29
# Total Faux Négatifs : 52

# %%
import os
import cv2
import numpy as np
from pathlib import Path

def find_corrupted_images(data_dir, threshold_black_percent=0.10):
    """
    Identifie les images qui ont trop de pixels noirs (bords/masques).
    threshold_black_percent : Si plus de 10% de l'image est noir pur (0), on la flag.
    """
    bad_images = []
    
    # Parcourir récursivement
    for root, dirs, files in os.walk(data_dir):
        for file in files:
            if file.lower().endswith(('.png', '.jpg', '.jpeg')):
                filepath = os.path.join(root, file)
                
                # Lire l'image en gris
                img = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)
                
                if img is None:
                    continue
                
                # Compter les pixels noirs (valeur proche de 0)
                # On met < 5 car parfois la compression JPG fait que le noir n'est pas exactement 0
                black_pixels = np.sum(img < 5)
                total_pixels = img.size
                ratio = black_pixels / total_pixels
                
                if ratio > threshold_black_percent:
                    bad_images.append((filepath, ratio))

    return bad_images

# Utilisation
ROOT_DIR = "./data/organized" # Ton dossier de train/val/test
bad_imgs = find_corrupted_images(ROOT_DIR)

print(f"Images problématiques trouvées : {len(bad_imgs)}")

# Afficher quelques exemples pour vérifier avant de supprimer
for path, ratio in bad_imgs[:5]:
    print(f"{path} -> {ratio*100:.2f}% de noir")

# Si tu es confiant, tu peux décommenter ceci pour les supprimer (ou les déplacer)
# for path, _ in bad_imgs:
#     os.remove(path)
# Out:
# Images problématiques trouvées : 98
# ./data/organized/train/S1SAR_UnBalanced_400by400_Class_0/460_5400_3000_img_lHgjbs0x2eQq1CKp_GBR_cls_0.jpg -> 27.59% de noir
# ./data/organized/train/S1SAR_UnBalanced_400by400_Class_0/39_3000_600_img_JkLqOgrRUbExe4fW_GBR_cls_0.jpg -> 10.29% de noir
# ./data/organized/train/S1SAR_UnBalanced_400by400_Class_0/2417_1800_8200_img_EppU8Z5MCiREy7AA_GBR_cls_0.jpg -> 61.09% de noir
# ./data/organized/train/S1SAR_UnBalanced_400by400_Class_0/1019_12400_4000_img_2A8VePMGEX2nNmAa_GBR_cls_0.jpg -> 62.95% de noir
# ./data/organized/train/S1SAR_UnBalanced_400by400_Class_0/1586_4600_6200_img_03Q3PAMUQOZKM0H5_GBR_cls_0.jpg -> 45.77% de noir
